# %%
import pandas as pd
import numpy as np
# %matplotlib inline
import h5py

# %%
df = pd.read_table('directory.csv',sep=',',engine='python')

# %%
df
# Out:
#            Brand  Store Number                           Store Name  \
# 0      Starbucks  47370-257954                        Meritxell, 96
# 1      Starbucks  22331-212325                     Ajman Drive Thru
# 2      Starbucks  47089-256771                            Dana Mall
# 3      Starbucks  22126-218024                           Twofour 54
# 4      Starbucks  17127-178586                         Al Ain Tower
# 5      Starbucks  17688-182164             Dalma Mall, Ground Floor
# 6      Starbucks  18182-182165                  Dalma Mall, Level 1
# 7      Starbucks  23359-229184                   Debenhams Yas Mall
# 8      Starbucks   30781-99022                     Khalidiya Street
# 9      Starbucks  20423-205465                    Eastern Mangroves
# 10     Starbucks  20424-205466                        Nation Towers
# 11     Starbucks   1579-122101  HCT Abu Dhabi Women's College Block
# 12     Starbucks  32595-122105          Standard Chartered Building
# ...

# %%
#select certain columns
df = df.drop(['Store Name', 'Ownership Type', 'Street Address', 'City', 'Phone Number', 'Timezone'], axis=1)

# %%
df.head(10)
# Out:
#        Brand  Store Number State/Province Country Postcode  Longitude  \
# 0  Starbucks  47370-257954              7      AD    AD500       1.53
# 1  Starbucks  22331-212325             AJ      AE      NaN      55.47
# 2  Starbucks  47089-256771             AJ      AE      NaN      55.47
# 3  Starbucks  22126-218024             AZ      AE      NaN      54.38
# 4  Starbucks  17127-178586             AZ      AE      NaN      54.54
# 5  Starbucks  17688-182164             AZ      AE      NaN      54.49
# 6  Starbucks  18182-182165             AZ      AE      NaN      54.49
# 7  Starbucks  23359-229184             AZ      AE      NaN      54.61
# 8  Starbucks   30781-99022             AZ      AE      NaN      55.69
# 9  Starbucks  20423-205465             AZ      AE      NaN      54.38
#
#    Latitude
# 0     42.51
# 1     25.42
# 2     25.39
# 3     24.48
# 4     24.51
# 5     24.40
# 6     24.40
# 7     24.46
# 8     24.19
# 9     24.48

# %%
#drop other countries
df = df[df.Country == 'US']

# %%
#check null zipcode
null_rows = df[df['Postcode'].isnull()]

# %%
null_rows
# Out:
#            Brand  Store Number State/Province Country Postcode  Longitude  \
# 21549  Starbucks  28180-250430             OH      US      NaN     -80.74
#
#        Latitude
# 21549     41.03

# %%
#drop it for now
df = df[df.notnull()]

# %%
#no null values in current df
df.isnull().values.any()
# Out:
# False

# %%
df.head(10)
# Out:
#            Brand  Store Number State/Province Country   Postcode  Longitude  \
# 11964  Starbucks   3513-125945             AK      US  995042300    -149.78
# 11965  Starbucks   74352-84449             AK      US  995073444    -149.84
# 11966  Starbucks  12449-152385             AK      US  995153596    -149.85
# 11967  Starbucks  24936-233524             AK      US      99515    -149.89
# 11968  Starbucks    8973-85630             AK      US  995152050    -149.86
# 11969  Starbucks   72788-84447             AK      US  995084218    -149.87
# 11970  Starbucks  79549-106150             AK      US  995081928    -149.82
# 11971  Starbucks  75988-107245             AK      US      99502    -149.98
# 11972  Starbucks   11426-99254             AK      US  995037247    -149.88
# 11973  Starbucks  20349-108249             AK      US      99504    -149.74
#
#        Latitude
# 11964     61.21
# 11965     61.14
# 11966     61.11
# 11967     61.13
# 11968     61.14
# 11969     61.19
# ...
